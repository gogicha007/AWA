# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine, text

#database settings
host = 'localhost'
dbname = 'awa_rural'
user = 'postgres' 
password = '123'

#Connection string: driver://username:passwod@server/database
engine = create_engine('postgresql+psycopg2://postgres:123@localhost:5433/awa_rural')

# %%
with engine.connect() as conn:
    result = conn.execute(text('select * from purchase;'))

print(result)
# Out:
# <sqlalchemy.engine.cursor.CursorResult object at 0x000001F241F56660>

# %%
file = pd.read_excel('Import_temp.xlsx')
# file = file.set_index('decl_date')
# print(file)
# file.info()
file[['decl_no','decl_date','seller','invoice','Inv_Date','truck','Description','qty','unit','Price exw']]
# Out:
#      decl_no   decl_date                      seller           invoice  \
# 0     C18046  2024-02-29  GEORG FICHER HAKAN PLASTIC  IHR2024000000215
# 1     C18046  2024-02-29  GEORG FICHER HAKAN PLASTIC  IHR2024000000216
# 2     C18046  2024-02-29  GEORG FICHER HAKAN PLASTIC  IHR2024000000224
# 3     C18046  2024-02-29  GEORG FICHER HAKAN PLASTIC  IHR2024000000225
# 4     C18046  2024-02-29  GEORG FICHER HAKAN PLASTIC  IHR2024000000227
# ...      ...         ...                         ...               ...
# 2259     NaN         NaN                         NaN               NaN
# 2260     NaN         NaN                         NaN               NaN
# 2261     NaN         NaN                         NaN               NaN
# 2262     NaN         NaN                         NaN               NaN
# 2263     NaN         NaN                         NaN               NaN
#
#        Inv_Date             truck             Description     qty unit  \
# 0    2024-02-26  VV370FV - BS676S  PE100 Pipe DN160, PN10  3267.0    m
# 1    2024-02-26  QQ124PQ - BB151U  PE100 Pipe DN160, PN10  3267.0    m
# 2    2024-02-26  QQ711LL - WW334W  PE100 Pipe DN160, PN10  3537.0    m
# 3    2024-02-26  XK540KX - RT443T  PE100 Pipe DN160, PN10  3240.0    m
# 4    2024-02-26  DZ195ZZ - BB821M  PE100 Pipe DN160, PN10   189.0    m
# ...         ...               ...                     ...     ...  ...
# 2259        NaT               NaN                     NaN     NaN  NaN
# 2260        NaT               NaN                     NaN     NaN  NaN
# 2261        NaT               NaN                     NaN     NaN  NaN
# 2262        NaT               NaN                     NaN     NaN  NaN
# 2263        NaT               NaN                     NaN     NaN  NaN
#
#       Price exw
# 0          6.71
# 1          6.71
# 2          6.71
# 3          6.71
# 4          6.71
# ...         ...
# 2259        NaN
# 2260        NaN
# 2261        NaN
# 2262        NaN
# 2263        NaN
#
# [2264 rows x 10 columns]
